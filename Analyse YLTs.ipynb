# %%
from natcat_analysis import read_losses, plot_return_period_curves, risk_measures

# %%
n_year = 1

# %%
# === Location sensitivity ===
hpp = read_losses(True, n_year, dir="Outputs/Nina")  # homogeneous=True, loc=False, intensity=False, damage=False
mmnhpp_FFF = read_losses(False, n_year, loc=False, p_loc=0.5, intensity=False, damage=False, dir="Outputs/Nina")
mmnhpp_TTF_50 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=False, dir="Outputs/Nina")
mmnhpp_TTF_80 = read_losses(False, n_year, loc=True, p_loc=0.8, intensity=True, damage=False, dir="Outputs/Nina")
mmnhpp_TTF_100 = read_losses(False, n_year, loc=True, p_loc=1.0, intensity=True, damage=False, dir="Outputs/Nina")

# === Main results ===
mmnhpp_FTF = read_losses(False, n_year, loc=False, p_loc=0.5, intensity=True, damage=False, dir="Outputs/Nina")
mmnhpp_TFF_50 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=False, damage=False, dir="Outputs/Nina")

# === Compound factor 1.1 ===
mmnhpp_FFT_CF110 = read_losses(False, n_year, loc=False, p_loc=0.5, intensity=False, damage=True, dir="Outputs/Nina")
hpp_CF110 = read_losses(True, n_year, loc=False, p_loc=0.5, intensity=False, damage=True, dir="Outputs/Nina")
mmnhpp_TTT_50_CF110 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=True, dir="Outputs/Nina")

# === Compound factor sensitivity (thresholds=0) ===
mmnhpp_TTT_50_CF100_thr0 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=True, dir="Outputs/Nina/threshold_0/compound_factor_100")
mmnhpp_TTT_50_CF105_thr0 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=True, dir="Outputs/Nina/threshold_0/compound_factor_105")
mmnhpp_TTT_50_CF110_thr0 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=True, dir="Outputs/Nina/threshold_0/compound_factor_110")
mmnhpp_TTT_50_CF115_thr0 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=True, dir="Outputs/Nina/threshold_0/compound_factor_115")
mmnhpp_TTT_50_CF120_thr0 = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=True, dir="Outputs/Nina/threshold_0/compound_factor_120")

# === Initial ENSO - Neutral ===
mmnhpp_HFF_neutral = read_losses(True, n_year, loc=False, intensity=False, damage=False, dir="Outputs/Neutral")
mmnhpp_FFF_neutral = read_losses(False, n_year, loc=False, intensity=False, damage=False, dir="Outputs/Neutral")
mmnhpp_TFF_50_neutral = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=False, damage=False, dir="Outputs/Neutral")
mmnhpp_FTF_neutral = read_losses(False, n_year, loc=False, p_loc=0.5, intensity=True, damage=False, dir="Outputs/Neutral")
mmnhpp_TTF_50_neutral = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=False, dir="Outputs/Neutral")

# === Initial ENSO - Nino ===
mmnhpp_HFF_nino = read_losses(True, n_year, loc=False, intensity=False, damage=False, dir="Outputs/Nino")
mmnhpp_FFF_nino = read_losses(False, n_year, loc=False, intensity=False, damage=False, dir="Outputs/Nino")
mmnhpp_TFF_50_nino = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=False, damage=False, dir="Outputs/Nino")
mmnhpp_FTF_nino = read_losses(False, n_year, loc=False, p_loc=0.5, intensity=True, damage=False, dir="Outputs/Nino")
mmnhpp_TTF_50_nino = read_losses(False, n_year, loc=True, p_loc=0.5, intensity=True, damage=False, dir="Outputs/Nino")

# %%
DATASET_COLORS = {
    id(hpp): "#000000",
    id(mmnhpp_FFF): "#7F7F7F",
    id(mmnhpp_TTF_50): "goldenrod",
    id(mmnhpp_TTF_80): "goldenrod",
    id(mmnhpp_TTF_100): "goldenrod",

    id(mmnhpp_TFF_50): "#D62728",
    id(mmnhpp_FTF): "#2CA02C",

    id(hpp_CF110): "#8C564B",
    id(mmnhpp_FFT_CF110): "tab:blue",
    id(mmnhpp_TTT_50_CF110): "tab:pink",

    id(mmnhpp_TTT_50_CF100_thr0): "tab:purple",
    id(mmnhpp_TTT_50_CF105_thr0): "tab:purple",
    id(mmnhpp_TTT_50_CF110_thr0): "tab:purple",
    id(mmnhpp_TTT_50_CF115_thr0): "tab:purple",
    id(mmnhpp_TTT_50_CF120_thr0): "tab:purple",

    id(mmnhpp_HFF_neutral): "#000000",
    id(mmnhpp_FFF_neutral): "#7F7F7F",
    id(mmnhpp_TFF_50_neutral): "#D62728",
    id(mmnhpp_FTF_neutral): "#2CA02C",
    id(mmnhpp_TTF_50_neutral): "goldenrod",

    id(mmnhpp_HFF_nino): "#000000",
    id(mmnhpp_FFF_nino): "#7F7F7F",
    id(mmnhpp_TFF_50_nino): "#D62728",
    id(mmnhpp_FTF_nino): "#2CA02C",
    id(mmnhpp_TTF_50_nino): "goldenrod",
}

# %%
DATASET_LINESTYLES = {
    id(hpp): "-",
    id(mmnhpp_FFF): "-",
    id(mmnhpp_TTF_50): "-",
    id(mmnhpp_TTF_80): "-.",
    id(mmnhpp_TTF_100): ":",

    id(mmnhpp_TFF_50): "-",
    id(mmnhpp_FTF): "-",

    id(hpp_CF110): "-",
    id(mmnhpp_FFT_CF110): "-",
    id(mmnhpp_TTT_50_CF110): "-",

    id(mmnhpp_TTT_50_CF100_thr0): ":",
    id(mmnhpp_TTT_50_CF105_thr0): "--",
    id(mmnhpp_TTT_50_CF110_thr0): (0, (3, 1)),
    id(mmnhpp_TTT_50_CF115_thr0): "-.",
    id(mmnhpp_TTT_50_CF120_thr0): "-",

    id(mmnhpp_HFF_neutral): "-",
    id(mmnhpp_FFF_neutral): "-",
    id(mmnhpp_TFF_50_neutral): "-",
    id(mmnhpp_FTF_neutral): "-",
    id(mmnhpp_TTF_50_neutral): "-",

    id(mmnhpp_HFF_nino): "-",
    id(mmnhpp_FFF_nino): "-",
    id(mmnhpp_TFF_50_nino): "-",
    id(mmnhpp_FTF_nino): "-",
    id(mmnhpp_TTF_50_nino): "-",
}

# %%
# labels_dict = {
#     # === Location sensitivity ===
#     r"Naïve HPP                          ": hpp,
#     r"MMNHPP                              ": mmnhpp_FFF,
#     r"Cyclogenesis ($p=0.5$) & Intensity  ": mmnhpp_TTF_50,
#     r"Cyclogenesis ($p=0.8$) & Intensity  ": mmnhpp_TTF_80,
#     r"Cyclogenesis ($p=1$) & Intensity    ": mmnhpp_TTF_100,

#     # === Main results ===
#     r"Intensity                          ": mmnhpp_FTF,
#     r"Cyclogenesis ($p=0.5$)            ": mmnhpp_TFF_50,
    
#     # === Compound factor 1.1 ===
#     r"Compound events ($\alpha=1.1$)     ": mmnhpp_FFT_CF110,
#     r"Naïve HPP & Compound events ($\alpha=1.1$) ": hpp_CF110,
#     r"All ($\alpha=1.1$)                 ": mmnhpp_TTT_50_CF110,

#     # === Compound factor sensitivity (thresholds=0) ===
#     r"All ($\alpha=1$)                   ": mmnhpp_TTT_50_CF100_thr0,
#     r"All ($\alpha=1.05$)                ": mmnhpp_TTT_50_CF105_thr0,
#     r"All ($\alpha=1.1$)                 ": mmnhpp_TTT_50_CF110_thr0,
#     r"All ($\alpha=1.15$)                ": mmnhpp_TTT_50_CF115_thr0,
#     r"All ($\alpha=1.2$)                 ": mmnhpp_TTT_50_CF120_thr0,

#     # === Initial ENSO – Neutral ===
#     r"Naïve HPP                          ": mmnhpp_HFF_neutral,
#     r"MMNHPP                              ": mmnhpp_FFF_neutral,
#     r"Cyclogenesis ($p=0.5$)             ": mmnhpp_TFF_50_neutral,
#     r"Intensity                           ": mmnhpp_FTF_neutral,
#     r"Cyclogenesis ($p=0.5$) & Intensity ": mmnhpp_TTF_50_neutral,

#     # === Initial ENSO – Nino ===
#     r"Naïve HPP                          ": mmnhpp_HFF_nino,
#     r"MMNHPP                              ": mmnhpp_FFF_nino,
#     r"Cyclogenesis ($p=0.5$)             ": mmnhpp_TFF_50_nino,
#     r"Intensity                           ": mmnhpp_FTF_nino,
#     r"Cyclogenesis ($p=0.5$) & Intensity ": mmnhpp_TTF_50_nino,
# }

# %%
# plot_return_period_curves(
#     [
#         # === Location sensitivity ===
#         hpp,
#         mmnhpp_FFF,
#         mmnhpp_TTF_50,
#         mmnhpp_TTF_80,
#         mmnhpp_TTF_100,

#         # === Main results ===
#         mmnhpp_TFF_50,
#         mmnhpp_FTF,

#         # === Compound factor 1.1 ===
#         hpp_CF110,
#         mmnhpp_FFT_CF110,
#         mmnhpp_TTT_50_CF110,

#         # === Compound factor sensitivity (thresholds=0) ===
#         mmnhpp_TTT_50_CF100_thr0,
#         mmnhpp_TTT_50_CF105_thr0,
#         mmnhpp_TTT_50_CF110_thr0,
#         mmnhpp_TTT_50_CF115_thr0,
#         mmnhpp_TTT_50_CF120_thr0,

#         # === Initial ENSO – Neutral ===
#         mmnhpp_HFF_neutral,
#         mmnhpp_FFF_neutral,
#         mmnhpp_TFF_50_neutral,
#         mmnhpp_FTF_neutral,
#         mmnhpp_TTF_50_neutral,

#         # === Initial ENSO – Nino ===
#         mmnhpp_HFF_nino,
#         mmnhpp_FFF_nino,
#         mmnhpp_TFF_50_nino,
#         mmnhpp_FTF_nino,
#         mmnhpp_TTF_50_nino,
#     ],
#     legend_labels=labels_dict,
#     savefig=False
# )

# %%
plot_combos = {
    f"v2_lu_garrido-{n_year}y-location-sensitivity.png": [
        hpp,
        mmnhpp_FFF,
        mmnhpp_TTF_50,
        mmnhpp_TTF_80,
        mmnhpp_TTF_100,
    ],
    f"v2_lu_garrido-{n_year}y.png": [
        hpp,
        mmnhpp_FFF,
        mmnhpp_TFF_50,
        mmnhpp_FTF,
        mmnhpp_TTF_50,
    ],
    f"v2_lu_garrido-{n_year}y-consecutive-damages.png": [
        hpp,
        hpp_CF110,
        mmnhpp_FFT_CF110,
        mmnhpp_TTF_50,
        mmnhpp_TTT_50_CF110,
    ],
    f"v2_lu_garrido-{n_year}y-alpha-sensitivity.png": [
        hpp,
        mmnhpp_FFF,
        mmnhpp_TTT_50_CF100_thr0,
        mmnhpp_TTT_50_CF105_thr0,
        mmnhpp_TTT_50_CF110_thr0,
        mmnhpp_TTT_50_CF115_thr0,
        mmnhpp_TTT_50_CF120_thr0,
    ],
    f"v2_lu_garrido-{n_year}y-Neutral.png": [
        mmnhpp_HFF_neutral,
        mmnhpp_FFF_neutral,
        mmnhpp_TFF_50_neutral,
        mmnhpp_FTF_neutral,
        mmnhpp_TTF_50_neutral,
    ],
    f"v2_lu_garrido-{n_year}y-Nino.png": [
        mmnhpp_HFF_nino,
        mmnhpp_FFF_nino,
        mmnhpp_TFF_50_nino,
        mmnhpp_FTF_nino,
        mmnhpp_TTF_50_nino,
    ],
}

# %%
labels_combos = {
    f"v2_lu_garrido-{n_year}y-location-sensitivity.png": {
        r"Naïve HPP                          ": hpp,
        r"MMNHPP                              ": mmnhpp_FFF,
        r"Cyclogenesis ($p=0.5$) & Intensity  ": mmnhpp_TTF_50,
        r"Cyclogenesis ($p=0.8$) & Intensity  ": mmnhpp_TTF_80,
        r"Cyclogenesis ($p=1$) & Intensity    ": mmnhpp_TTF_100,
    },
    f"v2_lu_garrido-{n_year}y.png": {
        r"Naïve HPP                          ": hpp,
        r"MMNHPP                              ": mmnhpp_FFF,
        r"Cyclogenesis ($p=0.5$)            ": mmnhpp_TFF_50,
        r"Intensity                          ": mmnhpp_FTF,
        r"Cyclogenesis ($p=0.5$) & Intensity ": mmnhpp_TTF_50,
    },
    f"v2_lu_garrido-{n_year}y-consecutive-damages.png": {
        r"Naïve HPP                          ": hpp,
        r"Naïve HPP & Compound events ($\alpha=1.1$) ": hpp_CF110,
        r"Cyclogenesis ($p=0.5$) & Intensity  ": mmnhpp_TTF_50,
        r"Compound events ($\alpha=1.1$)     ": mmnhpp_FFT_CF110,
        r"All ($\alpha=1.1$)                 ": mmnhpp_TTT_50_CF110,
    },
    f"v2_lu_garrido-{n_year}y-alpha-sensitivity.png": {
        r"Naïve HPP                          ": hpp,
        r"MMNHPP                              ": mmnhpp_FFF,
        r"All ($\alpha=1$)                   ": mmnhpp_TTT_50_CF100_thr0,
        r"All ($\alpha=1.05$)                ": mmnhpp_TTT_50_CF105_thr0,
        r"All ($\alpha=1.1$)                 ": mmnhpp_TTT_50_CF110_thr0,
        r"All ($\alpha=1.15$)                ": mmnhpp_TTT_50_CF115_thr0,
        r"All ($\alpha=1.2$)                 ": mmnhpp_TTT_50_CF120_thr0,
    },
    f"v2_lu_garrido-{n_year}y-Neutral.png": {
        r"Naïve HPP                          ": mmnhpp_HFF_neutral,
        r"MMNHPP                              ": mmnhpp_FFF_neutral,
        r"Cyclogenesis ($p=0.5$)             ": mmnhpp_TFF_50_neutral,
        r"Intensity                           ": mmnhpp_FTF_neutral,
        r"Cyclogenesis ($p=0.5$) & Intensity ": mmnhpp_TTF_50_neutral,
    },
    f"v2_lu_garrido-{n_year}y-Nino.png": {
        r"Naïve HPP                          ": mmnhpp_HFF_nino,
        r"MMNHPP                              ": mmnhpp_FFF_nino,
        r"Cyclogenesis ($p=0.5$)             ": mmnhpp_TFF_50_nino,
        r"Intensity                           ": mmnhpp_FTF_nino,
        r"Cyclogenesis ($p=0.5$) & Intensity ": mmnhpp_TTF_50_nino,
    },
}

# %%
for combo_name, losses_list in plot_combos.items():
    combo_labels = labels_combos[combo_name]

    plot_return_period_curves(
        losses_per_sim=losses_list,
        legend_labels=combo_labels,
        figsize=(18,10),     
        savefig=True,
        save_dir=f"v3_figures/{combo_name}",
        dataset_colors=DATASET_COLORS,
        dataset_linestyles=DATASET_LINESTYLES,
        # y_max=9e9        
    )
    print(f"Plot generated for: {combo_name}")

# %%
risk_measures(
    [
        # === Location sensitivity ===
        hpp,
        mmnhpp_FFF,
        mmnhpp_TTF_50,
        mmnhpp_TTF_80,
        mmnhpp_TTF_100,

        # === Main results ===
        mmnhpp_FTF,
        mmnhpp_TFF_50,

        # === Compound factor 1.1 ===
        mmnhpp_FFT_CF110,
        hpp_CF110,
        mmnhpp_TTT_50_CF110,

        # === Compound factor sensitivity (thresholds=0) ===
        mmnhpp_TTT_50_CF100_thr0,
        mmnhpp_TTT_50_CF105_thr0,
        mmnhpp_TTT_50_CF110_thr0,
        mmnhpp_TTT_50_CF115_thr0,
        mmnhpp_TTT_50_CF120_thr0,

        # === Initial ENSO – Neutral ===
        mmnhpp_HFF_neutral,
        mmnhpp_FFF_neutral,
        mmnhpp_TFF_50_neutral,
        mmnhpp_FTF_neutral,
        mmnhpp_TTF_50_neutral,

        # === Initial ENSO – Nino ===
        mmnhpp_HFF_nino,
        mmnhpp_FFF_nino,
        mmnhpp_TFF_50_nino,
        mmnhpp_FTF_nino,
        mmnhpp_TTF_50_nino,
    ],
    column_labels=labels_dict,
    units=10**6,
)

# %%
# labels_dict = {
#     # === Location sensitivity ===
#     r"Naïve HPP                          ": hpp,
#     r"Cyclogenesis ($p=0.5$) & Intensity  ": mmnhpp_TTF_50,
    
#     # === Compound factor 1.1 ===
#     r"Compound events ($\alpha=1.1$)     ": mmnhpp_FFT_CF110,
#     r"Naïve HPP & Compound events ($\alpha=1.1$) ": hpp_CF110,
#     r"All ($\alpha=1.1$)                 ": mmnhpp_TTT_50_CF110,

# }

# %%
# risk_measures(
#     [
#         # === Location sensitivity ===
#         hpp,
#         hpp_CF110,
#         mmnhpp_FFT_CF110,
#         mmnhpp_TTF_50,
#         mmnhpp_TTT_50_CF110,
#     ],
#     column_labels=labels_dict,
#     units=10**6,
# )
